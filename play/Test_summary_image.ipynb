# %%
# %matplotlib widget
import matplotlib.pyplot as plt

# %%
import caiman as cm
import matplotlib.pyplot as plt
import numpy as np
#different matplotlib backend for better plots
import matplotlib
matplotlib.rcParams['backend'] = 'TkAgg'
##

# Other imports
import glob
import time
import natsort
import pickle as pkl
import seaborn

# %%
results = pkl.load(open(r"C:\Users\student\PythonProject\ResultsDB_F_Frame_Files_.p", "rb"))                 
times = results['times']                                                    
frame_increments =  results['frame_increments']                             
cn_filters =  results['cn_filters']                                         
pnr_list =  results['pnr_list']

# %%
# Example data (replace this with your actual data)
#parameter_values = [1, 2, 3, 4, 5]
#runtime_values = [10.2, 15.1, 12.5, 18.7, 20.0]

frames_taken = [(37.564 / frame*1000) for frame in frame_increments] 
parameter_values = frame_increments
runtime_values = [round(t,2) for t in times]

plt.figure(figsize=(10, 6))  # Optional: Set the figure size

# Create a scatter plot
plt.scatter(parameter_values, runtime_values, color='blue', marker='o', label='Runs')
plt.scatter(parameter_values, runtime_values, color='blue', marker='o', label='Runs')
# Add labels and title
plt.xlabel('Parameter')
plt.ylabel('Runtime')
plt.title('Algorithm Runtime vs. Parameter')
plt.legend()

# Show the plot
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Out:
# [(37, 56400.0),
#  (37, 62666.666666666664),
#  (37, 70500.0),
#  (37, 80571.42857142857),
#  (37, 94000.0),
#  (37, 112800.0),
#  (37, 141000.0),
#  (37, 188000.0),
#  (37, 282000.0),
#  (37, 564000.0)]
